# %%
# %sql
--g_fact_trips is 1:1 OBT style business-ready table which can be treated as a sandbox to build more complex queries out of regular scope, data redundancy is sacrifice for ultimate flexibility of tables of such nature

CREATE OR REPLACE TABLE nyc_taxis_weather.gold_nyc_taxis.g_fact_trips CLONE nyc_taxis_weather.silver_nyc_taxis.s_nyc_taxis_weather_oct_dec
